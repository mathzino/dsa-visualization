# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_jakarta_indonesia_covid  = pd.read_csv("../data/Data Indonesia dan Jakarta.csv")
data_jakarta_indonesia_covid.fillna(0, inplace=True)
data_jakarta_indonesia_covid
# Out:
#           Tanggal Positif (Indonesia) Dirawat (Indonesia) Sembuh (Indonesia)  \
# 0     29/01/2020                    0                   0                  0
# 1     01/03/2020                    0                   0                  0
# 2     02/03/2020                    2                   2                  0
# 3     03/03/2020                    2                   2                  0
# 4     04/03/2020                    2                   2                  0
# ...           ...                 ...                 ...                ...
# 1213  26/06/2023                    0                   0                  0
# 1214  27/06/2023                    0                   0                  0
# 1215  28/06/2023                    0                   0                  0
# 1216  29/06/2023                    0                   0                  0
# 1217  30/06/2023                    0                   0                  0
#
# ...

# %%
data_jakarta_indonesia_covid['Tanggal'].str.strip()
data_jakarta_indonesia_covid['Tanggal'] = pd.to_datetime(data_jakarta_indonesia_covid['Tanggal'], format='%d/%M/%Y',exact=False).dt.date
for column in data_jakarta_indonesia_covid.columns:
    for index, row in data_jakarta_indonesia_covid.iterrows():
        value = row[column]
        if isinstance(value, str):
            cleaned_value = value.replace(",", "")
            converted_value = int(float(cleaned_value))
            data_jakarta_indonesia_covid.at[index, column] = converted_value

# %%
column_data_covid=[
    "Positif (Indonesia)", "Positif (Jakarta)",
    "Dirawat (Indonesia)", "Dirawat (Jakarta)",
    "Sembuh (Indonesia)", "Sembuh (Jakarta)",
    "Meninggal (Indonesia)", "Meninggal (Jakarta)",
    "Meninggal Harian (Indonesia)", "Meninggal Harian (Jakarta)",
    "Sembuh Harian (Indonesia)", "Sembuh Harian (Jakarta)",
    "Self-Isolation (Jakarta)", "Self-Isolation Harian (Jakarta)",
    "Dirawat Harian (Indonesia)", "Dirawat Harian (Jakarta)",
    "Positif Harian (Indonesia)", "Positif Harian (Jakarta)",
    "Positif Aktif (Jakarta)", "Positif Aktif Harian (Jakarta)"
]


fig, ax = plt.subplots(ncols=2, nrows=10, figsize=(10, 35))
for i, column in enumerate(column_data_covid):
    sns.lineplot(data_jakarta_indonesia_covid[column] , ax=ax[i//2, i%2] )
    ax[i//2, i%2].set_title("line of {}".format(column),fontsize=11)

# plt.tight_layout() 
plt.show()
